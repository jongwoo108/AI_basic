# %% [markdown]
# #### CSV파일로 데이터 다루기

# %% [markdown]
# ##### 04-1 CSV 데이터 알아보기

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\jongw\\OneDrive\\바탕 화면\\포트폴리오\\점프 투 파이썬'

# %%
cd C:\Users\jongw\OneDrive\바탕 화면\포트폴리오\점프 투 파이썬
# Out:
# C:\Users\jongw\OneDrive\바탕 화면\포트폴리오\점프 투 파이썬

# %%
import csv, os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jongw\\OneDrive\\바탕 화면\\포트폴리오\\점프 투 파이썬'

# %%
os.listdir()
# Out:
# ['04_csv_file.ipynb',
#  'a.csv',
#  'b.csv',
#  'c.csv',
#  'd.csv',
#  'example2.csv',
#  'new_1.csv',
#  'peopel.csv',
#  'people.csv',
#  'workspace.code-workspace']

# %%
f = open('c.csv', 'r', encoding = '949')
c = csv.reader(f)
c

# %% [markdown]
# * 엑셀파일 open할 때 한글 깨짐 문제 해결법\
# 인코딩 데이터 - 데이터 가져오기 - 파일 - 텍스트/CSV - 'utf-8', 'cp949' 모두 안됐는데 949로 인코딩하니 문제가 해결되었다.\
# https://teddylee777.github.io/pandas/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0-%ED%95%9C%EA%B8%80%EA%B9%A8%EC%A7%90%ED%98%84%EC%83%81-%ED%95%B4%EA%B2%B0%EB%B0%A9%EB%B2%95/

# %%
for i in c:
    print(i)
# Out:
# ['국어', '영어', '수학']
# ['90', '80', '100']

# %%
c_list = []
for i in c:
    print(i)
    c_list.append(i)

# %%
c_list
# Out:
# []

# %% [markdown]
# c_list 객체에 값이 텅 빈 이유는 앞에서 csv.reader(f)로 c.csv파일을 읽은 값을 c 객체에 저장하면서 커서가 맨 마지막으로 이동했기 때문이다.\
# 다시 파일을 처음부터 읽기 위해서는 seek() 함수를 사용해 커서를 처음으로 이동해야 한다.

# %%
f.seek(0)
# Out:
# 0

# %%
for i in c:
    print(i)
    c_list.append(i)
# Out:
# ['국어', '영어', '수학']
# ['90', '80', '100']

# %%
c_list
# Out:
# [['국어', '영어', '수학'], ['90', '80', '100']]

# %%
def opencsv(filename):
    f = open(filename, 'r', encoding = '949')
    reader = csv.reader(f)
    output = []
    for i in reader:
        output.append(i)
    return output
    f.close()

# %%
opencsv('example2.csv')
# Out:
# [['이름', '국어', '영어', '수학'],
#  ['a', '90', '80', '100'],
#  ['b', '80', '90', '90'],
#  ['c', '100', '80', '60']]

# %%
os.listdir()
# Out:
# ['04_csv_file.ipynb',
#  'a.csv',
#  'b.csv',
#  'c.csv',
#  'd.csv',
#  'example2.csv',
#  'new_1.csv',
#  'peopel.csv',
#  'people.csv',
#  'workspace.code-workspace']

# %%
a = [['구', '전체', '내국인', '외국인'], 
     ['관악구', '519864', '502089', '17775'],
     ['강남구', '547602', '542498', '5104'],
     ['송파구', '686181', '679247', '6934'],
     ['강동구', '428547', '424235', '4312']]

# %%
f = open('abc.csv', 'w', newline = '', encoding='949')

# %%
csvobject = csv.writer(f, delimiter=',')

# %%
csvobject.writerow(a)
f.close()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import csv

data = [['구', '전체', '내국인', '외국인'],
        ['관악구', '519864', '502089', '17775'],
        ['강남구', '547602', '542498', '5104'],
        ['송파구', '686181', '679247', '6934'],
        ['강동구', '428547', '424235', '4312']]

with open('abcd.csv', 'w', newline='', encoding='949') as f:
    csv_writer = csv.writer(f, delimiter=',')
    for row in data:
        csv_writer.writerow(row)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def writecsv(filename, the_list):
    with open(filename, 'w', newline='') as f:
        a = csv.writer(f, delimiter=',')
        a.writerows(the_list)
