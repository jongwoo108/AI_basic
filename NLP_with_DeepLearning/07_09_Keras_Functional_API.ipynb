# %% [markdown]
# # 딥 러닝을 이용한 자연어 처리 입문

# %% [markdown]
# [구글 코랩에서 실행하기](https://colab.research.google.com/drive/1wwqNyRuN23-yyxVFch7A6bwl2X7hElZ9?usp=sharing)

# %% [markdown]
# https://wikidocs.net/38861

# %% [markdown]
# 07-09 케라스의 함수형 API(Keras Functional API)

# %% [markdown]
# 앞서 구현한 선형, 로지스틱, 소프트맥스 회귀 모델들과 케라스 훑어보기 실습에서 배운 케라스의 모델 설계 방식은 Sequential API을 사용한 것입니다. 그런데 Sequential API는 여러층을 공유하거나 다양한 종류의 입력과 출력을 사용하는 등의 복잡한 모델을 만드는 일에는 한계가 있습니다. 이번에는 더욱 복잡한 모델을 생성할 수 있는 방식인 Functional API(함수형 API)에 대해서 알아봅니다.

# %% [markdown]
# Functional API에 대한 자세한 소개는 케라스 공식 문서에서도 확인할 수 있습니다.
#
# 링크 : https://keras.io/getting-started/functional-api-guide/

# %% [markdown]
# 1. Sequential API로 만든 모델

# %% [markdown]
# 두 가지 API의 차이를 이해하기 위해서 앞서 배운 Sequential API를 사용하여 기본적인 모델을 만들어봅시다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(3, input_dim = 4, activation = 'softmax'))

# %% [markdown]
# 위와 같은 방식은 직관적이고 편리하지만 단순히 층을 쌓는 것만으로는 구현할 수 없는 복잡한 신경망을 구현할 수 없습니다. 따라서 초심자에게 적합한 API이지만, 전문가가 되기 위해서는 결과적으로 Functional API를 학습해야 합니다.

# %% [markdown]
# 2. Functional API로 만든 모델

# %% [markdown]
# Functional API는 각 층을 일종의 함수(function)로서 정의합니다. 그리고 각 함수를 조합하기 위한 연산자들을 제공하는데, 이를 이용하여 신경망을 설계합니다. Functional API로 FFNN, RNN 등 다양한 모델을 만들면서 기존의 sequential API와의 차이를 이해해봅시다.

# %% [markdown]
# - Functional API는 입력의 크기(shape)를 명시한 입력층(Input layer)을 모델의 앞단에 정의해주어야 합니다.

# %% [markdown]
# 1) 전결합 피드 포워드 신경망(Fully-connected FFNN)

# %% [markdown]
# Sequential API와는 다르게 functional API에서는 입력 데이터의 크기(shape)를 인자로 입력층을 정의해주어야 합니다. 피드 포워드 신경망(Fully-connected FFNN)을 만든다고 가정해보겠습니다.

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# %%
imputs = Input(shape = (10,))

# %% [markdown]
# 위의 코드는 10개의 입력을 받는 입력층을 보여줍니다. 위의 코드에 은닉층과 출력층을 추가해봅시다.

# %%
inputs = Input(shape = (10,))
hidden1 = Dense(64, activation = 'relu')(inputs) #<- 새로 추가
hidden2 = Dense(64, activation = 'relu')(hidden1) # <- 새로 추가
output = Dense(1, activation = 'sigmoid')(hidden2) # <- 새로 추가

# %% [markdown]
# 위의 코드를 하나의 모델로 구성해보겠습니다. 이는 Model에 입력 텐서와 출력 텐서를 정의하여 완성됩니다.

# %%
inputs  = Input(shape = (10,))
hidden1 = Dense(64, activation = 'relu')(inputs)
hidden2 = Dense(64, activation = 'relu')(hidden1)
output = Dense(1, activation = 'sigmoid')(hidden2)
model = Model(inputs = inputs, outputs = output) # <- 새로 추가

# %% [markdown]
# 지금까지의 내용을 정리하면 다음과 같습니다.
#
# - Input() 함수에 입력의 크기를 정의합니다.
# - 이전층을 다음층 함수의 입력으로 사용하고, 변수에 할당합니다.
# - Model() 함수에 입력과 출력을 정의합니다.
#
# 이를 model로 저장하면 sequential API를 사용할 때와 마찬가지로 model.compile, model.fit 등을 사용 가능합니다.

# %%
model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# model.fit(data, labels)

# %% [markdown]
# 이번에는 변수명을 달리해서 FFNN을 만들어보겠습니다. 이번에는 은닉층과 출력층의 변수를 전부 x로 통일하였습니다.

# %%
inputs = Input(shape=(10,))
x = Dense(8, activation = 'relu')(inputs)
x = Dense(4, activation = 'relu')(x)
x = Dense(1, activation = 'linear')(x)
model = Model(inputs, x)

# %% [markdown]
# 이번에는 위에서 배운 내용을 바탕으로 선형 회귀와 로지스틱 회귀를 Functional API로 구현해봅시다.

# %% [markdown]
# 2) 선형 회귀(Linear Regression)

# %% [markdown]
# 앞서 ( https://wikidocs.net/111472 ) Sequential API로 구현했던 선형 회귀를 Functional API로 구현해봅시다.

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model

X = [1, 2, 3, 4, 5, 6, 7, 8, 9] # 공부하는 시간
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] # 각 공부하는 시간에 맵핑되는 성적

inputs = Input(shape = (1, ))
output = Dense(1, activation = 'linear')(inputs)
linear_model = Model(inputs, output)

sgd = optimizers.SGD(lr=0.01)

linear_model.compile(optimizer = sgd, loss = 'mse', metrics = ['mse'])
linear_model.fit(X, y, epochs = 300)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/300
# 1/1 [==============================] - 0s 453ms/step - loss: 3990.1958 - mse: 3990.1958
# Epoch 2/300
# 1/1 [==============================] - 0s 10ms/step - loss: 492.0529 - mse: 492.0529
# Epoch 3/300
# 1/1 [==============================] - 0s 10ms/step - loss: 61.6313 - mse: 61.6313
# Epoch 4/300
# 1/1 [==============================] - 0s 10ms/step - loss: 8.6698 - mse: 8.6698
# Epoch 5/300
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1520 - mse: 2.1520
# Epoch 6/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3488 - mse: 1.3488
# Epoch 7/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2487 - mse: 1.2487
# Epoch 8/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2351 - mse: 1.2351
# Epoch 9/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2322 - mse: 1.2322
# Epoch 10/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2306 - mse: 1.2306
# Epoch 11/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2292 - mse: 1.2292
# Epoch 12/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2278 - mse: 1.2278
# Epoch 13/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2264 - mse: 1.2264
# Epoch 14/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2250 - mse: 1.2250
# Epoch 15/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2237 - mse: 1.2237
# Epoch 16/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2223 - mse: 1.2223
# Epoch 17/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2210 - mse: 1.2210
# Epoch 18/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2197 - mse: 1.2197
# Epoch 19/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2184 - mse: 1.2184
# Epoch 20/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2171 - mse: 1.2171
# Epoch 21/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2158 - mse: 1.2158
# Epoch 22/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2145 - mse: 1.2145
# Epoch 23/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2132 - mse: 1.2132
# Epoch 24/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2120 - mse: 1.2120
# Epoch 25/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2107 - mse: 1.2107
# Epoch 26/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2095 - mse: 1.2095
# Epoch 27/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2083 - mse: 1.2083
# Epoch 28/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.2071 - mse: 1.2071
# Epoch 29/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2059 - mse: 1.2059
# Epoch 30/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2047 - mse: 1.2047
# Epoch 31/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2035 - mse: 1.2035
# Epoch 32/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2023 - mse: 1.2023
# Epoch 33/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2011 - mse: 1.2011
# Epoch 34/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2000 - mse: 1.2000
# Epoch 35/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1988 - mse: 1.1988
# Epoch 36/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1977 - mse: 1.1977
# Epoch 37/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1965 - mse: 1.1965
# Epoch 38/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1954 - mse: 1.1954
# Epoch 39/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1943 - mse: 1.1943
# Epoch 40/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1932 - mse: 1.1932
# Epoch 41/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1921 - mse: 1.1921
# Epoch 42/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1910 - mse: 1.1910
# Epoch 43/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1900 - mse: 1.1900
# Epoch 44/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1889 - mse: 1.1889
# Epoch 45/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1878 - mse: 1.1878
# Epoch 46/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1868 - mse: 1.1868
# Epoch 47/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1858 - mse: 1.1858
# Epoch 48/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1847 - mse: 1.1847
# Epoch 49/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1837 - mse: 1.1837
# Epoch 50/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1827 - mse: 1.1827
# Epoch 51/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1817 - mse: 1.1817
# Epoch 52/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1807 - mse: 1.1807
# Epoch 53/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1797 - mse: 1.1797
# Epoch 54/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1787 - mse: 1.1787
# Epoch 55/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1777 - mse: 1.1777
# Epoch 56/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1768 - mse: 1.1768
# Epoch 57/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1758 - mse: 1.1758
# Epoch 58/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1749 - mse: 1.1749
# Epoch 59/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1739 - mse: 1.1739
# Epoch 60/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1730 - mse: 1.1730
# Epoch 61/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1721 - mse: 1.1721
# Epoch 62/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1711 - mse: 1.1711
# Epoch 63/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1702 - mse: 1.1702
# Epoch 64/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1693 - mse: 1.1693
# Epoch 65/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1684 - mse: 1.1684
# Epoch 66/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1675 - mse: 1.1675
# Epoch 67/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1666 - mse: 1.1666
# Epoch 68/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1658 - mse: 1.1658
# Epoch 69/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1649 - mse: 1.1649
# Epoch 70/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1640 - mse: 1.1640
# Epoch 71/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1632 - mse: 1.1632
# Epoch 72/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1623 - mse: 1.1623
# Epoch 73/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1615 - mse: 1.1615
# Epoch 74/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1607 - mse: 1.1607
# Epoch 75/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1598 - mse: 1.1598
# Epoch 76/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1590 - mse: 1.1590
# Epoch 77/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1582 - mse: 1.1582
# Epoch 78/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1574 - mse: 1.1574
# Epoch 79/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1566 - mse: 1.1566
# Epoch 80/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1558 - mse: 1.1558
# Epoch 81/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1550 - mse: 1.1550
# Epoch 82/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1542 - mse: 1.1542
# Epoch 83/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1535 - mse: 1.1535
# Epoch 84/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1527 - mse: 1.1527
# Epoch 85/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1519 - mse: 1.1519
# Epoch 86/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1512 - mse: 1.1512
# Epoch 87/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1504 - mse: 1.1504
# Epoch 88/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1497 - mse: 1.1497
# Epoch 89/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1490 - mse: 1.1490
# Epoch 90/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1482 - mse: 1.1482
# Epoch 91/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1475 - mse: 1.1475
# Epoch 92/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1468 - mse: 1.1468
# Epoch 93/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1461 - mse: 1.1461
# Epoch 94/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1454 - mse: 1.1454
# Epoch 95/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1447 - mse: 1.1447
# Epoch 96/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1440 - mse: 1.1440
# Epoch 97/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1433 - mse: 1.1433
# Epoch 98/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1426 - mse: 1.1426
# Epoch 99/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1419 - mse: 1.1419
# Epoch 100/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1412 - mse: 1.1412
# Epoch 101/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1406 - mse: 1.1406
# Epoch 102/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1399 - mse: 1.1399
# Epoch 103/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1393 - mse: 1.1393
# Epoch 104/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1386 - mse: 1.1386
# Epoch 105/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1380 - mse: 1.1380
# Epoch 106/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1373 - mse: 1.1373
# Epoch 107/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1367 - mse: 1.1367
# Epoch 108/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1361 - mse: 1.1361
# Epoch 109/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1354 - mse: 1.1354
# Epoch 110/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1348 - mse: 1.1348
# Epoch 111/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1342 - mse: 1.1342
# Epoch 112/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1336 - mse: 1.1336
# Epoch 113/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1330 - mse: 1.1330
# Epoch 114/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1324 - mse: 1.1324
# Epoch 115/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1318 - mse: 1.1318
# Epoch 116/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1312 - mse: 1.1312
# Epoch 117/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1306 - mse: 1.1306
# Epoch 118/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1300 - mse: 1.1300
# Epoch 119/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1295 - mse: 1.1295
# Epoch 120/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1289 - mse: 1.1289
# Epoch 121/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1283 - mse: 1.1283
# Epoch 122/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1278 - mse: 1.1278
# Epoch 123/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1272 - mse: 1.1272
# Epoch 124/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1267 - mse: 1.1267
# Epoch 125/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1261 - mse: 1.1261
# Epoch 126/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1256 - mse: 1.1256
# Epoch 127/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1250 - mse: 1.1250
# Epoch 128/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1245 - mse: 1.1245
# Epoch 129/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1240 - mse: 1.1240
# Epoch 130/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1234 - mse: 1.1234
# Epoch 131/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1229 - mse: 1.1229
# Epoch 132/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.1224 - mse: 1.1224
# Epoch 133/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1219 - mse: 1.1219
# Epoch 134/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1214 - mse: 1.1214
# Epoch 135/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1209 - mse: 1.1209
# Epoch 136/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1204 - mse: 1.1204
# Epoch 137/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1199 - mse: 1.1199
# Epoch 138/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1194 - mse: 1.1194
# Epoch 139/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1189 - mse: 1.1189
# Epoch 140/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1184 - mse: 1.1184
# Epoch 141/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1179 - mse: 1.1179
# Epoch 142/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1175 - mse: 1.1175
# Epoch 143/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1170 - mse: 1.1170
# Epoch 144/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1165 - mse: 1.1165
# Epoch 145/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1161 - mse: 1.1161
# Epoch 146/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1156 - mse: 1.1156
# Epoch 147/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1151 - mse: 1.1151
# Epoch 148/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1147 - mse: 1.1147
# Epoch 149/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1142 - mse: 1.1142
# Epoch 150/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1138 - mse: 1.1138
# Epoch 151/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1133 - mse: 1.1133
# Epoch 152/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1129 - mse: 1.1129
# Epoch 153/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1125 - mse: 1.1125
# Epoch 154/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1120 - mse: 1.1120
# Epoch 155/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1116 - mse: 1.1116
# Epoch 156/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1112 - mse: 1.1112
# Epoch 157/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1108 - mse: 1.1108
# Epoch 158/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1104 - mse: 1.1104
# Epoch 159/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1099 - mse: 1.1099
# Epoch 160/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1095 - mse: 1.1095
# Epoch 161/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1091 - mse: 1.1091
# Epoch 162/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1087 - mse: 1.1087
# Epoch 163/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1083 - mse: 1.1083
# Epoch 164/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1079 - mse: 1.1079
# Epoch 165/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1075 - mse: 1.1075
# Epoch 166/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1071 - mse: 1.1071
# Epoch 167/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1068 - mse: 1.1068
# Epoch 168/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1064 - mse: 1.1064
# Epoch 169/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1060 - mse: 1.1060
# Epoch 170/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1056 - mse: 1.1056
# Epoch 171/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1052 - mse: 1.1052
# Epoch 172/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1049 - mse: 1.1049
# Epoch 173/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1045 - mse: 1.1045
# Epoch 174/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1041 - mse: 1.1041
# Epoch 175/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1038 - mse: 1.1038
# Epoch 176/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1034 - mse: 1.1034
# Epoch 177/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1030 - mse: 1.1030
# Epoch 178/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1027 - mse: 1.1027
# Epoch 179/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1023 - mse: 1.1023
# Epoch 180/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1020 - mse: 1.1020
# Epoch 181/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1016 - mse: 1.1016
# Epoch 182/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1013 - mse: 1.1013
# Epoch 183/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1010 - mse: 1.1010
# Epoch 184/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1006 - mse: 1.1006
# Epoch 185/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1003 - mse: 1.1003
# Epoch 186/300
# 1/1 [==============================] - 0s 28ms/step - loss: 1.1000 - mse: 1.1000
# Epoch 187/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0996 - mse: 1.0996
# Epoch 188/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0993 - mse: 1.0993
# Epoch 189/300
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0990 - mse: 1.0990
# Epoch 190/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0987 - mse: 1.0987
# Epoch 191/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0983 - mse: 1.0983
# Epoch 192/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0980 - mse: 1.0980
# Epoch 193/300
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0977 - mse: 1.0977
# Epoch 194/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0974 - mse: 1.0974
# Epoch 195/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0971 - mse: 1.0971
# Epoch 196/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0968 - mse: 1.0968
# Epoch 197/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0965 - mse: 1.0965
# Epoch 198/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0962 - mse: 1.0962
# Epoch 199/300
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0959 - mse: 1.0959
# Epoch 200/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0956 - mse: 1.0956
# Epoch 201/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0953 - mse: 1.0953
# Epoch 202/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0950 - mse: 1.0950
# Epoch 203/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0947 - mse: 1.0947
# Epoch 204/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0944 - mse: 1.0944
# Epoch 205/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0942 - mse: 1.0942
# Epoch 206/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0939 - mse: 1.0939
# Epoch 207/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0936 - mse: 1.0936
# Epoch 208/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0933 - mse: 1.0933
# Epoch 209/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0931 - mse: 1.0931
# Epoch 210/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0928 - mse: 1.0928
# Epoch 211/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0925 - mse: 1.0925
# Epoch 212/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0922 - mse: 1.0922
# Epoch 213/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0920 - mse: 1.0920
# Epoch 214/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0917 - mse: 1.0917
# Epoch 215/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0915 - mse: 1.0915
# Epoch 216/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0912 - mse: 1.0912
# Epoch 217/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0909 - mse: 1.0909
# Epoch 218/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0907 - mse: 1.0907
# Epoch 219/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0904 - mse: 1.0904
# Epoch 220/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0902 - mse: 1.0902
# Epoch 221/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0899 - mse: 1.0899
# Epoch 222/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0897 - mse: 1.0897
# Epoch 223/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0894 - mse: 1.0894
# Epoch 224/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0892 - mse: 1.0892
# Epoch 225/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0890 - mse: 1.0890
# Epoch 226/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0887 - mse: 1.0887
# Epoch 227/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0885 - mse: 1.0885
# Epoch 228/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0882 - mse: 1.0882
# Epoch 229/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0880 - mse: 1.0880
# Epoch 230/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0878 - mse: 1.0878
# Epoch 231/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0876 - mse: 1.0876
# Epoch 232/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0873 - mse: 1.0873
# Epoch 233/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0871 - mse: 1.0871
# Epoch 234/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0869 - mse: 1.0869
# Epoch 235/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0867 - mse: 1.0867
# Epoch 236/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0864 - mse: 1.0864
# Epoch 237/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0862 - mse: 1.0862
# Epoch 238/300
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0860 - mse: 1.0860
# Epoch 239/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0858 - mse: 1.0858
# Epoch 240/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0856 - mse: 1.0856
# Epoch 241/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0854 - mse: 1.0854
# Epoch 242/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0852 - mse: 1.0852
# Epoch 243/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0850 - mse: 1.0850
# Epoch 244/300
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0847 - mse: 1.0847
# Epoch 245/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0845 - mse: 1.0845
# Epoch 246/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0843 - mse: 1.0843
# Epoch 247/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0841 - mse: 1.0841
# Epoch 248/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0839 - mse: 1.0839
# Epoch 249/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0837 - mse: 1.0837
# Epoch 250/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0835 - mse: 1.0835
# Epoch 251/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0834 - mse: 1.0834
# Epoch 252/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0832 - mse: 1.0832
# Epoch 253/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0830 - mse: 1.0830
# Epoch 254/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0828 - mse: 1.0828
# Epoch 255/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0826 - mse: 1.0826
# Epoch 256/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0824 - mse: 1.0824
# Epoch 257/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0822 - mse: 1.0822
# Epoch 258/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0820 - mse: 1.0820
# Epoch 259/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0819 - mse: 1.0819
# Epoch 260/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0817 - mse: 1.0817
# Epoch 261/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0815 - mse: 1.0815
# Epoch 262/300
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0813 - mse: 1.0813
# Epoch 263/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0811 - mse: 1.0811
# Epoch 264/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0810 - mse: 1.0810
# Epoch 265/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0808 - mse: 1.0808
# Epoch 266/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0806 - mse: 1.0806
# Epoch 267/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0805 - mse: 1.0805
# Epoch 268/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0803 - mse: 1.0803
# Epoch 269/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0801 - mse: 1.0801
# Epoch 270/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0800 - mse: 1.0800
# Epoch 271/300
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0798 - mse: 1.0798
# Epoch 272/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0796 - mse: 1.0796
# Epoch 273/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0795 - mse: 1.0795
# Epoch 274/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0793 - mse: 1.0793
# Epoch 275/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0791 - mse: 1.0791
# Epoch 276/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0790 - mse: 1.0790
# Epoch 277/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0788 - mse: 1.0788
# Epoch 278/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0787 - mse: 1.0787
# Epoch 279/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0785 - mse: 1.0785
# Epoch 280/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0784 - mse: 1.0784
# Epoch 281/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0782 - mse: 1.0782
# Epoch 282/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0781 - mse: 1.0781
# Epoch 283/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0779 - mse: 1.0779
# Epoch 284/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0778 - mse: 1.0778
# Epoch 285/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0776 - mse: 1.0776
# Epoch 286/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0775 - mse: 1.0775
# Epoch 287/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0773 - mse: 1.0773
# Epoch 288/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0772 - mse: 1.0772
# Epoch 289/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0770 - mse: 1.0770
# Epoch 290/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0769 - mse: 1.0769
# Epoch 291/300
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0768 - mse: 1.0768
# Epoch 292/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0766 - mse: 1.0766
# Epoch 293/300
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0765 - mse: 1.0765
# Epoch 294/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0764 - mse: 1.0764
# Epoch 295/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0762 - mse: 1.0762
# Epoch 296/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0761 - mse: 1.0761
# Epoch 297/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0759 - mse: 1.0759
# Epoch 298/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0758 - mse: 1.0758
# Epoch 299/300
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0757 - mse: 1.0757
# Epoch 300/300
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0756 - mse: 1.0756

# %% [markdown]
# 3) 로지스틱 회귀(Logistic Regression)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

inputs = Input(shape = (3,))
output = Dense(1, activation = 'sigmoid')(inputs)
logistic_model = Model(inputs, output)

# %% [markdown]
# 4) 다중 입력을 받는 모델(model that accepts multiple inputs)

# %% [markdown]
# functional API를 사용하면 아래와 같이 다중 입력과 다중 출력을 가지는 모델도 만들 수 있습니다.

# %%
# 최종 완성된 다중 입력, 다중 출력 모델의 예
model = Model(inputs = [a1, a2], outputs = [b1, b2, b3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8681f59c7736> in <cell line: 2>()
#       1 # 최종 완성된 다중 입력, 다중 출력 모델의 예
# ----> 2 model = Model(inputs = [a1, a2], outputs = [b1, b2, b3])
#
# NameError: name 'a1' is not defined

# %% [markdown]
# 이번에는 다중 입력을 받는 모델을 입력층부터 출력층까지 설계해보겠습니다.

# %%
from tensorflow.keras.layers import Input, Dense, concatenate
from tensorflow.keras.models import Model

# %%
# 두 개의 입력층으 ㄹ정의
inputA = Input(shape = (64, ))
inputB = Input(shape = (128, ))

# %%
#첫번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
x = Dense(16, activation = 'relu')(inputA)
x = Dense(8, activation = 'relu')(x)
x = Model(inputs = inputA, outputs = x)

# %%
# 두번째 입력층으로부터 분기되어 진행되는 인공 신경망을 정의
y = Dense(64, activation = 'relu')(inputB)
y = Dense(32, activation = 'relu')(y)
y = Dense(8, activation = 'relu')(y)
y = Model(inputs = inputB, outputs = y)

# %%
# 두개의 인공 신경망의 출력을 연결(concatenate)
result = concatenate([x.output, y.output])

z = Dense(2, activation = 'relu')(result)
z = Dense(1, activation = 'linear')(z)

model = Model(inputs = [x.input, y.input], outputs = z)

# %% [markdown]
# 위 모델은 두 개의 입력층으로부터 분기되어 진행된 후 마지막에는 하나의 출력을 예측하는 모델입니다.

# %% [markdown]
# 5) RNN(Recurrence Neural Network) 은닉층 사용하기

# %% [markdown]
# 이번에는 RNN 은닉층을 가지는 모델을 설계해봅시다. 여기서는 하나의 특성(feature)에 50개의 시점(time-step)을 입력으로 받는 모델을 설계해보겠습니다. RNN에 대한 구체적인 내용은 다음 챕터인 RNN 챕터에서 배웁니다.

# %%
from tensorflow.keras.layers import Input, Dense, LSTM
from tensorflow.keras.models import Model

inputs = Input(shape = (50, 1))
lstm_layer = LSTM(10)(inputs)
x = Dense(10, activation = 'relu')(lstm_layer)
output = Dense(1, activation = 'sigmoid')(x)

model = Model(inputs = inputs, outputs = output)

# %% [markdown]
# 6) 다르게 보이지만 동일한 표기

# %% [markdown]
# 케라스의 Functional API가 익숙하지 않은 상태에서 Functional API를 사용한 코드를 보다가 혼동할 수 있는 점이 한 가지 있습니다. 바로 동일한 의미를 가지지만, 하나의 줄로 표현할 수 있는 코드를 두 개의 줄로 표현한 경우입니다.

# %%
result = Dense(128)(inputs)

# %% [markdown]
# 위 코드는 아래와 같이 두 개의 줄로 표현할 수 있습니다.

# %%
dense = Dense(128)
result = dense(inputs)
